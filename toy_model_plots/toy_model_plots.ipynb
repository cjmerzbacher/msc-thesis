# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import pandas as pd

# %%
dual_control = pd.read_csv('dual_control.csv')
upstream_repression = pd.read_csv('upstream_repression.csv')
downstream_activation = pd.read_csv('downstream_activation.csv')

# %%
endpoint = 'v2'
circuit_type = 'dual_control'
ss_data = locals()[circuit_type]

thetas_plot = ss_data.theta.unique()

 
fig = plt.figure()
fig, axs = plt.subplots(2, 5, figsize=(30, 10))

i=0; j=0
for theta in thetas_plot:
    data = ss_data.loc[ss_data.theta == theta]
    X = data.k1.unique()
    Y = data.k2.unique()
    Z = np.array(data[endpoint]).reshape((len(X), len(Y)))
    
    p= axs[i, j].contourf(X, Y, Z)
    axs[i, j].set_title(f'theta = {theta}')
    axs[i, j].set_xlabel('k1')
    axs[i, j].set_ylabel('k2')
    if j != 4:
        j+=1
    else:
        j=0
        i+=1
fig.suptitle(f'Steady state values of {endpoint} for {circuit_type}')
fig.tight_layout()
cbar = fig.colorbar(p, ax=axs.ravel().tolist(), shrink=0.9)
plt.show()

# %%
endpoint = 'v2'
circuit_type = 'downstream_activation'
ss_data = locals()[circuit_type]

thetas_plot = ss_data.theta.unique()

 
fig = plt.figure()
fig, axs = plt.subplots(2, 5, figsize=(30, 10))

i=0; j=0
for theta in thetas_plot:
    data = ss_data.loc[ss_data.theta == theta]
    X = data.k1.unique()
    Y = data.k2.unique()
    Z = np.array(data[endpoint]).reshape((len(X), len(Y)))
    
    p= axs[i, j].contourf(X, Y, Z)
    axs[i, j].set_title(f'theta = {theta}')
    axs[i, j].set_xlabel('k1')
    axs[i, j].set_ylabel('k2')
    if j != 4:
        j+=1
    else:
        j=0
        i+=1
fig.suptitle(f'Steady state values of {endpoint} for {circuit_type}')
fig.tight_layout() 
cbar = fig.colorbar(p, ax=axs.ravel().tolist(), shrink=0.9)
plt.show()

# %%
endpoint = 'v2'
circuit_type = 'upstream_repression'
ss_data = locals()[circuit_type]

thetas_plot = ss_data.theta.unique()

 
fig = plt.figure()
fig, axs = plt.subplots(2, 5, figsize=(30, 10))

i=0; j=0
for theta in thetas_plot:
    data = ss_data.loc[ss_data.theta == theta]
    X = data.k1.unique()
    Y = data.k2.unique()
    Z = np.array(data[endpoint]).reshape((len(X), len(Y)))
    
    p= axs[i, j].contourf(X, Y, Z)
    axs[i, j].set_title(f'theta = {theta}')
    axs[i, j].set_xlabel('k1')
    axs[i, j].set_ylabel('k2')
    if j != 4:
        j+=1
    else:
        j=0
        i+=1
fig.suptitle(f'Steady state values of {endpoint} for {circuit_type}')
fig.tight_layout()
cbar = fig.colorbar(p, ax=axs.ravel().tolist(), shrink=0.9)
plt.show()

# %%
data = ss_data.loc[ss_data.theta == 4.45]
X = data.k1.unique()
Y = data.k2.unique()
Z = np.array(data.v2).reshape((len(X), len(Y)))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
fig.colorbar(p, ax=ax)

# %%
conditions = np.array(ss_data[['k1', 'k2', 'theta']])
ax = plt.axes(projection='3d')
plt.colorbar
ax.scatter(conditions[:, 1], conditions[:, 0], conditions[:, 2], c=ss_data[['x1']], cmap='viridis', linewidth=0.5);
plt.show()
